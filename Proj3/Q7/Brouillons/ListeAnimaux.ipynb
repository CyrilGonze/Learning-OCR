# %%
import pandas as pd
df=pd.read_csv("FAOSTAT_Animaux.csv")

# %%
df=df.groupby("Produit").count().reset_index()

# %%
ListeAnimaux=df.drop(columns=["Code Domaine","Domaine","Code Pays","Pays","Code Élément","Élément","Code Produit","Code Année","Année","Valeur"])

# %%
ListeAnimaux.to_csv("ListeAnimaux.csv")

# %%
df
# Out:
#                      Produit  Code Domaine  Domaine  Code Pays  Pays  \
# 0           Abats Comestible           173      173        173   173
# 1   Animaux Aquatiques Autre            87       87         87    87
# 2               Beurre, Ghee           116      116        116   116
# 3               Cephalopodes           114      114        114   114
# 4                  Crustacés           146      146        146   146
# 5                      Crème            66       66         66    66
# 6     Graisses Animales Crue           173      173        173   173
# 7   Huiles de Foie de Poisso            63       63         63    63
# 8         Huiles de Poissons            96       96         96    96
# 9         Lait - Excl Beurre           170      170        170   170
# 10        Mollusques, Autres           111      111        111   111
# 11                     Oeufs           172      172        172   172
# 12                 Perciform           134      134        134   134
# ...
