# %%
import pandas as pd
df=pd.read_csv("FAOSTATvegetaux.csv")

# %%
df=df.groupby("Produit").count().reset_index()

# %%
df=df.drop(columns=["Domaine","Pays","Élément","Année","Valeur"])

# %%
ListeVegetaux=df

# %%
ListeVegetaux.to_csv("ListeVegtaux.csv")

# %%
ListeVegetaux
# Out:
#                      Produit
# 0            Agrumes, Autres
# 1     Alcool, non Comestible
# 2      Aliments pour enfants
# 3                     Ananas
# 4     Arachides Decortiquees
# 5                     Avoine
# 6                    Bananes
# 7          Bananes plantains
# 8                      Bière
# 9                        Blé
# 10      Boissons Alcooliques
# 11        Boissons Fermentés
# 12                      Café
# 13           Citrons & Limes
# 14        Coco (Incl Coprah)
# 15          Céréales, Autres
# 16                    Dattes
# 17        Edulcorants Autres
# 18             Feve de Cacao
# 19            Fruits, Autres
# 20                  Girofles
# 21    Graines Colza/Moutarde
# 22          Graines de coton
# 23      Graines de tournesol
# 24                  Haricots
# 25   Huil Plantes Oleif Autr
# 26    Huile Graines de Coton
# 27          Huile d'Arachide
# 28             Huile d'Olive
# 29             Huile de Coco
# ..                       ...
# ...
